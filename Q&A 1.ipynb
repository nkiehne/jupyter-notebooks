# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Intermediate Q&A 1
# ***

# %% [markdown]
# Agenda:
# * Tips and tricks for the challenge
#     * Layers, optimizers, losses, hyperparameters
#     * My solution
# * Q&A

# %% [markdown]
# # Useful layers
# ***
# `Dense` layers are fully-connected
# * $784$ input pixels for $n$ `Dense` neurons give $784n$ weights!
# * Each output depends on each input

# %% [markdown]
# `Conv2D` layers setup small *kernels* that are applied across the input
# * Only $k_w*k_h$ weights per neuron!
# <img src="https://anhreynolds.com/img/cnn.png" style="height:300px;">

# %% [markdown]
# # Useful layers 2
# ***
# `Pooling(w,h)` layers reduce the dimensionality of the input
# * `AvgPool2D`: Take the average value of each patch
# * `MaxPool2D`: Take the maximum value each patch
# * No weights and learning, but helps sorting out unecessary input

# %%
input_layer = keras.layers.Input((28,28,))
l = keras.layers.Reshape((28,28,1))(input_layer)

l = keras.layers.Conv2D(filters=32, kernel_size=(3,3), 
                        activation="relu", padding="same")(l)
l = keras.layers.AvgPool2D((2,2))(l)

l = keras.layers.Conv2D(filters=32, kernel_size=(3,3), 
                        activation="relu", padding="same")(l)
l = keras.layers.AvgPool2D((2,2))(l)

model = keras.models.Model(input_layer, l)
model.summary(50)
# Out:
# Model: "functional_7"
# __________________________________________________
# Layer (type)          Output Shape        Param #
# ==================================================
# input_7 (InputLayer)  [(None, 28, 28)]    0
# __________________________________________________
# reshape_6 (Reshape)   (None, 28, 28, 1)   0
# __________________________________________________
# conv2d_6 (Conv2D)     (None, 28, 28, 32)  320
# __________________________________________________
# average_pooling2d_6 ( (None, 14, 14, 32)  0
# __________________________________________________
# conv2d_7 (Conv2D)     (None, 14, 14, 32)  9248
# __________________________________________________
# average_pooling2d_7 ( (None, 7, 7, 32)    0
# ==================================================
# Total params: 9,568
# Trainable params: 9,568
# Non-trainable params: 0
# __________________________________________________

# %% [markdown]
# # Useful optimizers
# ***
# All optimizers in `keras` are based on gradient descent
# * Idea: A negative gradient indicates decreasing function values
# * The `learning_rate` determines how far to move into the steepest direction
#
# `SGD` is the vanilla gradient descent method
# * Gets stuck in local optima fast
#
# Others, like `Adam`, `Adamax`, `Adadelta` dynamically set learning rate
# * E.g based on gradient norms, dimensionality
# * In practice, they almost always outperform `SGD`

# %% [markdown]
# # Which to choose?
# ***
# The effectivity of an optimizer depends on the network and the training data
#
# Use case:
# * Proof of concept, i.e. "Wonder if this would learn anything"
#     * Start with standard methods, e.g. `SGD`
# * Scientific research
#     * Try any *reasonable* methods
# * Trying to beat Niklas
#     * Try out everything

# %% [markdown]
# # Useful losses
# ***
# Our problem involves classification. In almost all cases the one below works very well
# * `categorical_crossentropy` is a measure of closeness between discrete distributions
#     * I.e. set the parameters such that our model approximates the input distribution
#
# For classification it might also be interesting to play around with
# * `MSE`: Usually worse, but has its perks for some optimizers

# %% [markdown]
# # Hyperparameters
# ***
# Getting the most out of your model usually involves tuning hyperparameters:
# * `learning_rate`
#     * Large steps might skip over more local minima, but may also not converge
#     * Small steps might converge to local minima and never leave them again
#         * Decreasing the learning during training can help a lot!
# * `batch_size`
#     * Theoretically, `batch_size=1` has the fastest convergence properties
#         * But per epoch, not per second!
#     * Start with a `batch_size` that allows for rapid protoype training
#         * Depends on your hardware
#     * For promising candidates: Lower it until you see diminishing returns

# %% [markdown]
# # Try it out
# ***
# All of the design choices available are interconnected:
# * Network architecture
#     * Type of layers
#     * Activation functions
#     * Weights per layer
# * Optimizer
#     * Learning rate, momentum
#     * batch size
# * Losses
#
# There are no perfect solutions
# * It is a lot of trial and error
# * Very good solutions for scenario A might be far from good for scenario B

# %% [markdown]
# # My current solution
# ***
# Result of tons of trial and error.

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

def evaluate_model(model, x_test, y_test):
    num_weights = model.count_params()
    acc_metric = keras.metrics.CategoricalAccuracy()
    out = model(x_test)
    acc_metric.update_state(y_test, out)
    acc = acc_metric.result().numpy()
    return {"Test accuracy":acc, "Number of parameters":num_weights}

def get_data():
    (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
    y_train = keras.utils.to_categorical(y_train)
    y_test = keras.utils.to_categorical(y_test)

    return x_train, y_train, x_test, y_test

x_train, y_train, x_test, y_test = get_data()

# %%
input_layer = keras.layers.Input((28,28,))
l = keras.layers.Reshape((28,28,1))(input_layer)
l = keras.layers.AvgPool2D((2,2))(l)
l = keras.layers.Conv2D(3, 3, activation="sigmoid", padding="valid")(l)
l = keras.layers.Conv2D(1, 3, activation="sigmoid", padding="valid")(l)
l = keras.layers.AvgPool2D((3,3))(l)
l = keras.layers.Conv2D(10, 3, activation="softmax", padding="valid")(l)

l = keras.layers.Reshape((-1,))(l)

model = keras.models.Model(input_layer, l)
model.summary(50)
# Out:
# Model: "functional_1"
# __________________________________________________
# Layer (type)          Output Shape        Param #
# ==================================================
# input_1 (InputLayer)  [(None, 28, 28)]    0
# __________________________________________________
# reshape (Reshape)     (None, 28, 28, 1)   0
# __________________________________________________
# average_pooling2d (Av (None, 14, 14, 1)   0
# __________________________________________________
# conv2d (Conv2D)       (None, 12, 12, 3)   30
# __________________________________________________
# conv2d_1 (Conv2D)     (None, 10, 10, 1)   28
# __________________________________________________
# average_pooling2d_1 ( (None, 3, 3, 1)     0
# __________________________________________________
# conv2d_2 (Conv2D)     (None, 1, 1, 10)    100
# __________________________________________________
# reshape_1 (Reshape)   (None, 10)          0
# ==================================================
# Total params: 158
# Trainable params: 158
# Non-trainable params: 0
# __________________________________________________

# %%
model.compile("nadam", "categorical_crossentropy", ["accuracy"])

callbacks = [keras.callbacks.ReduceLROnPlateau(monitor="loss", factor=0.5, patience=3, verbose=1),
            keras.callbacks.EarlyStopping(monitor="loss", patience=5, min_delta=1e-6)]

_ = model.fit(x_train, y_train, epochs=1000, batch_size=1024, verbose=2, callbacks = callbacks)
print(evaluate_model(model, x_test, y_test))
# Out:
# Epoch 1/1000
# 59/59 - 0s - loss: 2.3113 - accuracy: 0.1004
# Epoch 2/1000
# 59/59 - 0s - loss: 2.2951 - accuracy: 0.1658
# Epoch 3/1000
# 59/59 - 0s - loss: 2.2882 - accuracy: 0.1348
# Epoch 4/1000
# 59/59 - 0s - loss: 2.2765 - accuracy: 0.1776
# Epoch 5/1000
# 59/59 - 0s - loss: 2.2533 - accuracy: 0.2410
# Epoch 6/1000
# 59/59 - 0s - loss: 2.2153 - accuracy: 0.3430
# Epoch 7/1000
# 59/59 - 0s - loss: 2.1628 - accuracy: 0.4279
# Epoch 8/1000
# 59/59 - 0s - loss: 2.0942 - accuracy: 0.5215
# Epoch 9/1000
# 59/59 - 0s - loss: 2.0099 - accuracy: 0.5750
# Epoch 10/1000
# 59/59 - 0s - loss: 1.9265 - accuracy: 0.6012
# Epoch 11/1000
# 59/59 - 0s - loss: 1.8468 - accuracy: 0.6214
# Epoch 12/1000
# 59/59 - 0s - loss: 1.7725 - accuracy: 0.6336
# Epoch 13/1000
# 59/59 - 0s - loss: 1.7035 - accuracy: 0.6446
# Epoch 14/1000
# 59/59 - 0s - loss: 1.6408 - accuracy: 0.6551
# Epoch 15/1000
# 59/59 - 0s - loss: 1.5838 - accuracy: 0.6631
# Epoch 16/1000
# 59/59 - 0s - loss: 1.5313 - accuracy: 0.6702
# Epoch 17/1000
# 59/59 - 0s - loss: 1.4809 - accuracy: 0.6793
# Epoch 18/1000
# 59/59 - 0s - loss: 1.4335 - accuracy: 0.6872
# Epoch 19/1000
# 59/59 - 0s - loss: 1.3910 - accuracy: 0.6946
# Epoch 20/1000
# 59/59 - 0s - loss: 1.3516 - accuracy: 0.7008
# Epoch 21/1000
# 59/59 - 0s - loss: 1.3153 - accuracy: 0.7071
# Epoch 22/1000
# 59/59 - 0s - loss: 1.2816 - accuracy: 0.7113
# Epoch 23/1000
# 59/59 - 0s - loss: 1.2500 - accuracy: 0.7162
# Epoch 24/1000
# 59/59 - 0s - loss: 1.2205 - accuracy: 0.7204
# Epoch 25/1000
# 59/59 - 0s - loss: 1.1926 - accuracy: 0.7243
# Epoch 26/1000
# 59/59 - 0s - loss: 1.1663 - accuracy: 0.7277
# Epoch 27/1000
# 59/59 - 0s - loss: 1.1413 - accuracy: 0.7305
# Epoch 28/1000
# 59/59 - 0s - loss: 1.1169 - accuracy: 0.7354
# Epoch 29/1000
# 59/59 - 0s - loss: 1.0935 - accuracy: 0.7394
# Epoch 30/1000
# 59/59 - 0s - loss: 1.0721 - accuracy: 0.7413
# Epoch 31/1000
# 59/59 - 0s - loss: 1.0516 - accuracy: 0.7448
# Epoch 32/1000
# 59/59 - 0s - loss: 1.0319 - accuracy: 0.7462
# Epoch 33/1000
# 59/59 - 0s - loss: 1.0133 - accuracy: 0.7488
# Epoch 34/1000
# 59/59 - 0s - loss: 0.9959 - accuracy: 0.7509
# Epoch 35/1000
# 59/59 - 0s - loss: 0.9794 - accuracy: 0.7532
# Epoch 36/1000
# 59/59 - 0s - loss: 0.9637 - accuracy: 0.7558
# Epoch 37/1000
# 59/59 - 0s - loss: 0.9483 - accuracy: 0.7579
# Epoch 38/1000
# 59/59 - 0s - loss: 0.9338 - accuracy: 0.7604
# Epoch 39/1000
# 59/59 - 0s - loss: 0.9196 - accuracy: 0.7624
# Epoch 40/1000
# Epoch 218/1000
# 59/59 - 0s - loss: 0.3771 - accuracy: 0.8804
# Epoch 219/1000
# 59/59 - 0s - loss: 0.3770 - accuracy: 0.8803
# Epoch 220/1000
# 59/59 - 0s - loss: 0.3765 - accuracy: 0.8809
# Epoch 221/1000
# 59/59 - 0s - loss: 0.3756 - accuracy: 0.8809
# Epoch 222/1000
# 59/59 - 0s - loss: 0.3756 - accuracy: 0.8803
# Epoch 223/1000
# 59/59 - 0s - loss: 0.3754 - accuracy: 0.8809
# Epoch 224/1000
# 59/59 - 0s - loss: 0.3747 - accuracy: 0.8812
# Epoch 225/1000
# 59/59 - 0s - loss: 0.3745 - accuracy: 0.8809
# Epoch 226/1000
# 59/59 - 0s - loss: 0.3740 - accuracy: 0.8810
# Epoch 227/1000
# 59/59 - 0s - loss: 0.3736 - accuracy: 0.8813
# Epoch 228/1000
# 59/59 - 0s - loss: 0.3733 - accuracy: 0.8817
# Epoch 229/1000
# 59/59 - 0s - loss: 0.3729 - accuracy: 0.8821
# Epoch 230/1000
# 59/59 - 0s - loss: 0.3723 - accuracy: 0.8820
# Epoch 231/1000
# 59/59 - 0s - loss: 0.3720 - accuracy: 0.8821
# Epoch 232/1000
# 59/59 - 0s - loss: 0.3717 - accuracy: 0.8821
# Epoch 233/1000
# 59/59 - 0s - loss: 0.3717 - accuracy: 0.8818
# Epoch 234/1000
# 59/59 - 0s - loss: 0.3709 - accuracy: 0.8822
# Epoch 235/1000
# 59/59 - 0s - loss: 0.3707 - accuracy: 0.8819
# Epoch 236/1000
# 59/59 - 0s - loss: 0.3703 - accuracy: 0.8828
# Epoch 237/1000
# 59/59 - 0s - loss: 0.3698 - accuracy: 0.8824
# Epoch 238/1000
# 59/59 - 0s - loss: 0.3696 - accuracy: 0.8827
# Epoch 239/1000
# 59/59 - 0s - loss: 0.3692 - accuracy: 0.8823
# Epoch 240/1000
# 59/59 - 0s - loss: 0.3688 - accuracy: 0.8830
# Epoch 241/1000
# 59/59 - 0s - loss: 0.3689 - accuracy: 0.8827
# Epoch 242/1000
# 59/59 - 0s - loss: 0.3684 - accuracy: 0.8833
# Epoch 243/1000
# 59/59 - 0s - loss: 0.3681 - accuracy: 0.8831
# Epoch 244/1000
# 59/59 - 0s - loss: 0.3680 - accuracy: 0.8831
# Epoch 245/1000
# 59/59 - 0s - loss: 0.3673 - accuracy: 0.8832
# Epoch 246/1000
# 59/59 - 0s - loss: 0.3671 - accuracy: 0.8834
# Epoch 247/1000
# 59/59 - 0s - loss: 0.3666 - accuracy: 0.8835
# Epoch 248/1000
# 59/59 - 0s - loss: 0.3662 - accuracy: 0.8837
# Epoch 249/1000
# 59/59 - 0s - loss: 0.3659 - accuracy: 0.8838
# Epoch 250/1000
# 59/59 - 0s - loss: 0.3657 - accuracy: 0.8841
# Epoch 251/1000
# 59/59 - 0s - loss: 0.3654 - accuracy: 0.8839
# Epoch 252/1000
# 59/59 - 0s - loss: 0.3653 - accuracy: 0.8839
# Epoch 253/1000
# 59/59 - 0s - loss: 0.3647 - accuracy: 0.8844
# Epoch 254/1000
# 59/59 - 0s - loss: 0.3644 - accuracy: 0.8838
# Epoch 255/1000
# 59/59 - 0s - loss: 0.3641 - accuracy: 0.8839
# Epoch 256/1000
# 59/59 - 0s - loss: 0.3640 - accuracy: 0.8840
# Epoch 257/1000
# 59/59 - 0s - loss: 0.3635 - accuracy: 0.8847
# Epoch 258/1000
# 59/59 - 0s - loss: 0.3632 - accuracy: 0.8847
# Epoch 259/1000
# 59/59 - 0s - loss: 0.3632 - accuracy: 0.8846
# Epoch 260/1000
# 59/59 - 0s - loss: 0.3628 - accuracy: 0.8846
# Epoch 261/1000
# 59/59 - 0s - loss: 0.3629 - accuracy: 0.8843
# Epoch 262/1000
# 59/59 - 0s - loss: 0.3619 - accuracy: 0.8847
# Epoch 263/1000
# 59/59 - 0s - loss: 0.3619 - accuracy: 0.8847
# Epoch 264/1000
# 59/59 - 0s - loss: 0.3617 - accuracy: 0.8844
# Epoch 265/1000
# 59/59 - 0s - loss: 0.3615 - accuracy: 0.8847
# Epoch 266/1000
# 59/59 - 0s - loss: 0.3612 - accuracy: 0.8852
# Epoch 267/1000
# 59/59 - 0s - loss: 0.3606 - accuracy: 0.8852
# Epoch 268/1000
# 59/59 - 0s - loss: 0.3605 - accuracy: 0.8852
# Epoch 269/1000
# 59/59 - 0s - loss: 0.3605 - accuracy: 0.8851
# Epoch 270/1000
# 59/59 - 0s - loss: 0.3600 - accuracy: 0.8852
# Epoch 271/1000
# 59/59 - 0s - loss: 0.3597 - accuracy: 0.8854
# Epoch 272/1000
# 59/59 - 0s - loss: 0.3595 - accuracy: 0.8858
# Epoch 273/1000
# 59/59 - 0s - loss: 0.3592 - accuracy: 0.8864
# Epoch 274/1000
# 59/59 - 0s - loss: 0.3592 - accuracy: 0.8856
# Epoch 275/1000
# 59/59 - 0s - loss: 0.3592 - accuracy: 0.8861
# Epoch 276/1000
# 59/59 - 0s - loss: 0.3586 - accuracy: 0.8855
# Epoch 277/1000
# 59/59 - 0s - loss: 0.3582 - accuracy: 0.8865
# Epoch 278/1000
# 59/59 - 0s - loss: 0.3585 - accuracy: 0.8858
# Epoch 279/1000
# 59/59 - 0s - loss: 0.3577 - accuracy: 0.8860
# Epoch 280/1000
# 59/59 - 0s - loss: 0.3578 - accuracy: 0.8859
# Epoch 281/1000
# 59/59 - 0s - loss: 0.3571 - accuracy: 0.8860
# Epoch 282/1000
# 59/59 - 0s - loss: 0.3572 - accuracy: 0.8863
# Epoch 283/1000
# 59/59 - 0s - loss: 0.3568 - accuracy: 0.8862
# Epoch 284/1000
# 59/59 - 0s - loss: 0.3566 - accuracy: 0.8862
# Epoch 285/1000
# 59/59 - 0s - loss: 0.3566 - accuracy: 0.8869
# Epoch 286/1000
# 59/59 - 0s - loss: 0.3563 - accuracy: 0.8860
# Epoch 287/1000
# 59/59 - 0s - loss: 0.3564 - accuracy: 0.8864
# Epoch 288/1000
# 59/59 - 0s - loss: 0.3559 - accuracy: 0.8863
# Epoch 289/1000
# 59/59 - 0s - loss: 0.3556 - accuracy: 0.8867
# Epoch 290/1000
# 59/59 - 0s - loss: 0.3555 - accuracy: 0.8869
# Epoch 291/1000
# 59/59 - 0s - loss: 0.3551 - accuracy: 0.8863
# Epoch 292/1000
# 59/59 - 0s - loss: 0.3550 - accuracy: 0.8865
# Epoch 293/1000
# 59/59 - 0s - loss: 0.3550 - accuracy: 0.8864
# Epoch 294/1000
# 59/59 - 0s - loss: 0.3547 - accuracy: 0.8863
# Epoch 295/1000
# 59/59 - 0s - loss: 0.3544 - accuracy: 0.8868
# Epoch 296/1000
# 59/59 - 0s - loss: 0.3538 - accuracy: 0.8870
# Epoch 297/1000
# 59/59 - 0s - loss: 0.3540 - accuracy: 0.8864
# Epoch 298/1000
# 59/59 - 0s - loss: 0.3538 - accuracy: 0.8873
# Epoch 299/1000
#
# Epoch 00299: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59/59 - 0s - loss: 0.3537 - accuracy: 0.8866
# Epoch 300/1000
# 59/59 - 0s - loss: 0.3528 - accuracy: 0.8873
# Epoch 301/1000
# 59/59 - 0s - loss: 0.3526 - accuracy: 0.8875
# Epoch 302/1000
# 59/59 - 0s - loss: 0.3523 - accuracy: 0.8871
# Epoch 303/1000
# 59/59 - 0s - loss: 0.3525 - accuracy: 0.8869
# Epoch 304/1000
# 59/59 - 0s - loss: 0.3525 - accuracy: 0.8873
# Epoch 305/1000
# 59/59 - 0s - loss: 0.3522 - accuracy: 0.8877
# Epoch 306/1000
# 59/59 - 0s - loss: 0.3519 - accuracy: 0.8873
# Epoch 307/1000
# 59/59 - 0s - loss: 0.3518 - accuracy: 0.8882
# Epoch 308/1000
# 59/59 - 0s - loss: 0.3516 - accuracy: 0.8870
# Epoch 309/1000
# 59/59 - 0s - loss: 0.3517 - accuracy: 0.8875
# Epoch 310/1000
# 59/59 - 0s - loss: 0.3516 - accuracy: 0.8875
# Epoch 311/1000
# 59/59 - 0s - loss: 0.3515 - accuracy: 0.8877
# Epoch 312/1000
# 59/59 - 0s - loss: 0.3513 - accuracy: 0.8876
# Epoch 313/1000
# 59/59 - 0s - loss: 0.3513 - accuracy: 0.8879
# Epoch 314/1000
# 59/59 - 0s - loss: 0.3515 - accuracy: 0.8879
# Epoch 315/1000
# 59/59 - 0s - loss: 0.3511 - accuracy: 0.8877
# Epoch 316/1000
# 59/59 - 0s - loss: 0.3509 - accuracy: 0.8879
# Epoch 317/1000
# 59/59 - 0s - loss: 0.3511 - accuracy: 0.8878
# Epoch 318/1000
# 59/59 - 0s - loss: 0.3508 - accuracy: 0.8880
# Epoch 319/1000
# 59/59 - 0s - loss: 0.3509 - accuracy: 0.8877
# Epoch 320/1000
# 59/59 - 0s - loss: 0.3506 - accuracy: 0.8882
# Epoch 321/1000
# 59/59 - 0s - loss: 0.3503 - accuracy: 0.8878
# Epoch 322/1000
# 59/59 - 0s - loss: 0.3504 - accuracy: 0.8878
# Epoch 323/1000
# 59/59 - 0s - loss: 0.3501 - accuracy: 0.8879
# Epoch 324/1000
# 59/59 - 0s - loss: 0.3500 - accuracy: 0.8885
# Epoch 325/1000
# 59/59 - 0s - loss: 0.3500 - accuracy: 0.8878
# Epoch 326/1000
#
# Epoch 00326: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 59/59 - 0s - loss: 0.3500 - accuracy: 0.8883
# Epoch 327/1000
# 59/59 - 0s - loss: 0.3495 - accuracy: 0.8886
# Epoch 328/1000
# 59/59 - 0s - loss: 0.3494 - accuracy: 0.8881
# Epoch 329/1000
# 59/59 - 0s - loss: 0.3492 - accuracy: 0.8883
# Epoch 330/1000
# 59/59 - 0s - loss: 0.3492 - accuracy: 0.8887
# Epoch 331/1000
# 59/59 - 0s - loss: 0.3490 - accuracy: 0.8883
# Epoch 332/1000
# 59/59 - 0s - loss: 0.3490 - accuracy: 0.8883
# Epoch 333/1000
# 59/59 - 0s - loss: 0.3491 - accuracy: 0.8885
# Epoch 334/1000
#
# Epoch 00334: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 59/59 - 0s - loss: 0.3490 - accuracy: 0.8886
# Epoch 335/1000
# 59/59 - 0s - loss: 0.3487 - accuracy: 0.8887
# Epoch 336/1000
# 59/59 - 0s - loss: 0.3486 - accuracy: 0.8888
# Epoch 337/1000
# 59/59 - 0s - loss: 0.3486 - accuracy: 0.8886
# Epoch 338/1000
#
# Epoch 00338: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 59/59 - 0s - loss: 0.3486 - accuracy: 0.8889
# Epoch 339/1000
# 59/59 - 0s - loss: 0.3484 - accuracy: 0.8888
# Epoch 340/1000
# 59/59 - 0s - loss: 0.3484 - accuracy: 0.8888
# Epoch 341/1000
# 59/59 - 0s - loss: 0.3484 - accuracy: 0.8887
# Epoch 342/1000
# 59/59 - 0s - loss: 0.3483 - accuracy: 0.8888
# Epoch 343/1000
# 59/59 - 0s - loss: 0.3483 - accuracy: 0.8889
# Epoch 344/1000
# 59/59 - 0s - loss: 0.3483 - accuracy: 0.8887
# Epoch 345/1000
#
# Epoch 00345: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 59/59 - 0s - loss: 0.3483 - accuracy: 0.8889
# Epoch 346/1000
# 59/59 - 0s - loss: 0.3482 - accuracy: 0.8890
# Epoch 347/1000
# 59/59 - 0s - loss: 0.3482 - accuracy: 0.8887
# Epoch 348/1000
# 59/59 - 0s - loss: 0.3482 - accuracy: 0.8887
# Epoch 349/1000
#
# Epoch 00349: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 59/59 - 0s - loss: 0.3482 - accuracy: 0.8889
# Epoch 350/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 351/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 352/1000
#
# Epoch 00352: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 353/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8888
# Epoch 354/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 355/1000
#
# Epoch 00355: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8890
# Epoch 356/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8890
# Epoch 357/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 358/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 359/1000
#
# Epoch 00359: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8888
# Epoch 360/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 361/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 362/1000
#
# Epoch 00362: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 363/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 364/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 365/1000
#
# Epoch 00365: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 366/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 367/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 368/1000
#
# Epoch 00368: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 369/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 370/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 371/1000
#
# Epoch 00371: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 372/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 373/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 374/1000
#
# Epoch 00374: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 375/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 376/1000
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# Epoch 377/1000
#
# Epoch 00377: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 59/59 - 0s - loss: 0.3481 - accuracy: 0.8889
# {'Test accuracy': 0.9014, 'Number of parameters': 158}

# %% [markdown]
# # Question time
