# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Intermediate Q&A 1
# ***

# %% [markdown]
# Agenda:
# * Tips and tricks for the challenge
#     * Layers, optimizers, losses, hyperparameters
#     * My solution
# * Q&A

# %% [markdown]
# # Useful layers
# ***
# `Dense` layers are fully-connected
# * $784$ input pixels for $n$ `Dense` neurons give $784n$ weights!
# * Each output depends on each input

# %% [markdown]
# `Conv2D` layers setup small *kernels* that are applied across the input
# * Only $k_w*k_h$ weights per neuron!
# <img src="https://anhreynolds.com/img/cnn.png" style="height:300px;">

# %% [markdown]
# # Useful layers 2
# ***
# `Pooling(w,h)` layers reduce the dimensionality of the input
# * `AvgPool2D`: Take the average value of each patch
# * `MaxPool2D`: Take the maximum value each patch
# * No weights and learning, but helps sorting out unecessary input

# %%
input_layer = keras.layers.Input((28,28,))
l = keras.layers.Reshape((28,28,1))(input_layer)

l = keras.layers.Conv2D(filters=32, kernel_size=(3,3), 
                        activation="relu", padding="same")(l)
l = keras.layers.AvgPool2D((2,2))(l)

l = keras.layers.Conv2D(filters=32, kernel_size=(3,3), 
                        activation="relu", padding="same")(l)
l = keras.layers.AvgPool2D((2,2))(l)

model = keras.models.Model(input_layer, l)
model.summary(50)
# Out:
# Model: "functional_7"
# __________________________________________________
# Layer (type)          Output Shape        Param #
# ==================================================
# input_7 (InputLayer)  [(None, 28, 28)]    0
# __________________________________________________
# reshape_6 (Reshape)   (None, 28, 28, 1)   0
# __________________________________________________
# conv2d_6 (Conv2D)     (None, 28, 28, 32)  320
# __________________________________________________
# average_pooling2d_6 ( (None, 14, 14, 32)  0
# __________________________________________________
# conv2d_7 (Conv2D)     (None, 14, 14, 32)  9248
# __________________________________________________
# average_pooling2d_7 ( (None, 7, 7, 32)    0
# ==================================================
# Total params: 9,568
# Trainable params: 9,568
# Non-trainable params: 0
# __________________________________________________

# %% [markdown]
# # Useful optimizers
# ***
# All optimizers in `keras` are based on gradient descent
# * Idea: A negative gradient indicates decreasing function values
# * The `learning_rate` determines how far to move into the steepest direction
#
# `SGD` is the vanilla gradient descent method
# * Gets stuck in local optima fast
#
# Others, like `Adam`, `Adamax`, `Adadelta` dynamically set learning rate
# * E.g based on gradient norms, dimensionality
# * In practice, they almost always outperform `SGD`

# %% [markdown]
# # Which to choose?
# ***
# The effectivity of an optimizer depends on the network and the training data
#
# Use case:
# * Proof of concept, i.e. "Wonder if this would learn anything"
#     * Start with standard methods, e.g. `SGD`
# * Scientific research
#     * Try any *reasonable* methods
# * Trying to beat Niklas
#     * Try out everything

# %% [markdown]
# # Useful losses
# ***
# Our problem involves classification. In almost all cases the one below works very well
# * `categorical_crossentropy` is a measure of closeness between discrete distributions
#     * I.e. set the parameters such that our model approximates the input distribution
#
# For classification it might also be interesting to play around with
# * `MSE`: Usually worse, but has its perks for some optimizers

# %% [markdown]
# # Hyperparameters
# ***
# Getting the most out of your model usually involves tuning hyperparameters:
# * `learning_rate`
#     * Large steps might skip over more local minima, but may also not converge
#     * Small steps might converge to local minima and never leave them again
#         * Decreasing the learning during training can help a lot!
# * `batch_size`
#     * Theoretically, `batch_size=1` has the fastest convergence properties
#         * But per epoch, not per second!
#     * Start with a `batch_size` that allows for rapid protoype training
#         * Depends on your hardware
#     * For promising candidates: Lower it until you see diminishing returns

# %% [markdown]
# # Try it out
# ***
# All of the design choices available are interconnected:
# * Network architecture
#     * Type of layers
#     * Activation functions
#     * Weights per layer
# * Optimizer
#     * Learning rate, momentum
#     * batch size
# * Losses
#
# There are no perfect solutions
# * It is a lot of trial and error
# * Very good solutions for scenario A might be far from good for scenario B

# %% [markdown]
# # My current solution
# ***
# Result of tons of trial and error.

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

def evaluate_model(model, x_test, y_test):
    num_weights = model.count_params()
    acc_metric = keras.metrics.CategoricalAccuracy()
    out = model(x_test)
    acc_metric.update_state(y_test, out)
    acc = acc_metric.result().numpy()
    return {"Test accuracy":acc, "Number of parameters":num_weights}

def get_data():
    (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
    y_train = keras.utils.to_categorical(y_train)
    y_test = keras.utils.to_categorical(y_test)

    return x_train, y_train, x_test, y_test

x_train, y_train, x_test, y_test = get_data()

# %%
tf.random.set_seed(1)

input_layer = keras.layers.Input((28,28,))
l = keras.layers.Reshape((28,28,1))(input_layer)
l = keras.layers.AvgPool2D((2,2))(l)
l = keras.layers.Conv2D(3, 3, activation="sigmoid", padding="valid")(l)
l = keras.layers.Conv2D(1, 3, activation="sigmoid", padding="valid")(l)
l = keras.layers.AvgPool2D((3,3))(l)
l = keras.layers.Conv2D(10, 3, activation="softmax", padding="valid")(l)

l = keras.layers.Reshape((-1,))(l)

model = keras.models.Model(input_layer, l)
model.summary(50)
# Out:
# Model: "functional_17"
# __________________________________________________
# Layer (type)          Output Shape        Param #
# ==================================================
# input_9 (InputLayer)  [(None, 28, 28)]    0
# __________________________________________________
# reshape_16 (Reshape)  (None, 28, 28, 1)   0
# __________________________________________________
# average_pooling2d_16  (None, 14, 14, 1)   0
# __________________________________________________
# conv2d_24 (Conv2D)    (None, 12, 12, 3)   30
# __________________________________________________
# conv2d_25 (Conv2D)    (None, 10, 10, 1)   28
# __________________________________________________
# average_pooling2d_17  (None, 3, 3, 1)     0
# __________________________________________________
# conv2d_26 (Conv2D)    (None, 1, 1, 10)    100
# __________________________________________________
# reshape_17 (Reshape)  (None, 10)          0
# ==================================================
# Total params: 158
# Trainable params: 158
# Non-trainable params: 0
# __________________________________________________

# %%
model.compile("nadam", "categorical_crossentropy", ["accuracy"])

callbacks = [keras.callbacks.ReduceLROnPlateau(monitor="loss", factor=0.5, patience=3, verbose=1),
            keras.callbacks.EarlyStopping(monitor="loss", patience=5, min_delta=1e-6)]

_ = model.fit(x_train, y_train, epochs=1000, batch_size=1024, verbose=2, callbacks = callbacks)
print(evaluate_model(model, x_test, y_test))
# Out:
# Epoch 1/1000
# 59/59 - 0s - loss: 2.3183 - accuracy: 0.0987
# Epoch 2/1000
# 59/59 - 0s - loss: 2.2952 - accuracy: 0.1422
# Epoch 3/1000
# 59/59 - 0s - loss: 2.2811 - accuracy: 0.1242
# Epoch 4/1000
# 59/59 - 0s - loss: 2.2589 - accuracy: 0.1469
# Epoch 5/1000
# 59/59 - 0s - loss: 2.2239 - accuracy: 0.1992
# Epoch 6/1000
# 59/59 - 0s - loss: 2.1729 - accuracy: 0.2957
# Epoch 7/1000
# 59/59 - 0s - loss: 2.1109 - accuracy: 0.3647
# Epoch 8/1000
# 59/59 - 0s - loss: 2.0447 - accuracy: 0.4726
# Epoch 9/1000
# 59/59 - 0s - loss: 1.9780 - accuracy: 0.5224
# Epoch 10/1000
# 59/59 - 0s - loss: 1.9159 - accuracy: 0.5637
# Epoch 11/1000
# 59/59 - 0s - loss: 1.8564 - accuracy: 0.5857
# Epoch 12/1000
# 59/59 - 0s - loss: 1.7996 - accuracy: 0.6066
# Epoch 13/1000
# 59/59 - 0s - loss: 1.7448 - accuracy: 0.6205
# Epoch 14/1000
# 59/59 - 0s - loss: 1.6912 - accuracy: 0.6356
# Epoch 15/1000
# 59/59 - 0s - loss: 1.6406 - accuracy: 0.6471
# Epoch 16/1000
# 59/59 - 0s - loss: 1.5928 - accuracy: 0.6575
# Epoch 17/1000
# 59/59 - 0s - loss: 1.5476 - accuracy: 0.6672
# Epoch 18/1000
# 59/59 - 0s - loss: 1.5050 - accuracy: 0.6768
# Epoch 19/1000
# 59/59 - 0s - loss: 1.4649 - accuracy: 0.6837
# Epoch 20/1000
# 59/59 - 0s - loss: 1.4270 - accuracy: 0.6922
# Epoch 21/1000
# 59/59 - 0s - loss: 1.3914 - accuracy: 0.6972
# Epoch 22/1000
# 59/59 - 0s - loss: 1.3580 - accuracy: 0.7034
# Epoch 23/1000
# 59/59 - 0s - loss: 1.3264 - accuracy: 0.7095
# Epoch 24/1000
# 59/59 - 0s - loss: 1.2969 - accuracy: 0.7141
# Epoch 25/1000
# 59/59 - 0s - loss: 1.2692 - accuracy: 0.7203
# Epoch 26/1000
# 59/59 - 0s - loss: 1.2430 - accuracy: 0.7229
# Epoch 27/1000
# 59/59 - 0s - loss: 1.2182 - accuracy: 0.7272
# Epoch 28/1000
# 59/59 - 0s - loss: 1.1947 - accuracy: 0.7319
# Epoch 29/1000
# 59/59 - 0s - loss: 1.1724 - accuracy: 0.7345
# Epoch 30/1000
# 59/59 - 0s - loss: 1.1512 - accuracy: 0.7384
# Epoch 31/1000
# 59/59 - 0s - loss: 1.1311 - accuracy: 0.7413
# Epoch 32/1000
# 59/59 - 0s - loss: 1.1120 - accuracy: 0.7432
# Epoch 33/1000
# 59/59 - 0s - loss: 1.0937 - accuracy: 0.7461
# Epoch 34/1000
# 59/59 - 0s - loss: 1.0760 - accuracy: 0.7484
# Epoch 35/1000
# 59/59 - 0s - loss: 1.0592 - accuracy: 0.7510
# Epoch 36/1000
# 59/59 - 0s - loss: 1.0431 - accuracy: 0.7543
# Epoch 37/1000
# 59/59 - 0s - loss: 1.0279 - accuracy: 0.7554
# Epoch 38/1000
# 59/59 - 0s - loss: 1.0135 - accuracy: 0.7584
# Epoch 39/1000
# 59/59 - 0s - loss: 0.9994 - accuracy: 0.7596
# Epoch 40/1000
# 59/59 - 0s - loss: 0.9860 - accuracy: 0.7616
# Epoch 41/1000
# 59/59 - 0s - loss: 0.9729 - accuracy: 0.7642
# Epoch 42/1000
# 59/59 - 0s - loss: 0.9603 - accuracy: 0.7660
# Epoch 43/1000
# 59/59 - 0s - loss: 0.9483 - accuracy: 0.7677
# Epoch 44/1000
# 59/59 - 0s - loss: 0.9366 - accuracy: 0.7698
# Epoch 45/1000
# 59/59 - 0s - loss: 0.9253 - accuracy: 0.7709
# 59/59 - 0s - loss: 0.3508 - accuracy: 0.8917
# Epoch 269/1000
# 59/59 - 0s - loss: 0.3503 - accuracy: 0.8911
# Epoch 270/1000
# 59/59 - 0s - loss: 0.3503 - accuracy: 0.8917
# Epoch 271/1000
# 59/59 - 0s - loss: 0.3491 - accuracy: 0.8918
# Epoch 272/1000
# 59/59 - 0s - loss: 0.3490 - accuracy: 0.8915
# Epoch 273/1000
# 59/59 - 0s - loss: 0.3490 - accuracy: 0.8920
# Epoch 274/1000
# 59/59 - 0s - loss: 0.3486 - accuracy: 0.8916
# Epoch 275/1000
# 59/59 - 0s - loss: 0.3486 - accuracy: 0.8920
# Epoch 276/1000
# 59/59 - 0s - loss: 0.3479 - accuracy: 0.8918
# Epoch 277/1000
# 59/59 - 0s - loss: 0.3475 - accuracy: 0.8920
# Epoch 278/1000
# 59/59 - 0s - loss: 0.3472 - accuracy: 0.8926
# Epoch 279/1000
# 59/59 - 0s - loss: 0.3473 - accuracy: 0.8926
# Epoch 280/1000
# 59/59 - 0s - loss: 0.3465 - accuracy: 0.8928
# Epoch 281/1000
# 59/59 - 0s - loss: 0.3464 - accuracy: 0.8929
# Epoch 282/1000
# 59/59 - 0s - loss: 0.3460 - accuracy: 0.8925
# Epoch 283/1000
# 59/59 - 0s - loss: 0.3454 - accuracy: 0.8937
# Epoch 284/1000
# 59/59 - 0s - loss: 0.3456 - accuracy: 0.8930
# Epoch 285/1000
# 59/59 - 0s - loss: 0.3446 - accuracy: 0.8929
# Epoch 286/1000
# 59/59 - 0s - loss: 0.3447 - accuracy: 0.8931
# Epoch 287/1000
# 59/59 - 0s - loss: 0.3442 - accuracy: 0.8935
# Epoch 288/1000
# 59/59 - 0s - loss: 0.3444 - accuracy: 0.8938
# Epoch 289/1000
# 59/59 - 0s - loss: 0.3437 - accuracy: 0.8936
# Epoch 290/1000
# 59/59 - 0s - loss: 0.3432 - accuracy: 0.8935
# Epoch 291/1000
# 59/59 - 0s - loss: 0.3432 - accuracy: 0.8936
# Epoch 292/1000
# 59/59 - 0s - loss: 0.3430 - accuracy: 0.8942
# Epoch 293/1000
# 59/59 - 0s - loss: 0.3426 - accuracy: 0.8941
# Epoch 294/1000
# 59/59 - 0s - loss: 0.3424 - accuracy: 0.8936
# Epoch 295/1000
# 59/59 - 0s - loss: 0.3423 - accuracy: 0.8941
# Epoch 296/1000
# 59/59 - 0s - loss: 0.3410 - accuracy: 0.8943
# Epoch 297/1000
# 59/59 - 0s - loss: 0.3411 - accuracy: 0.8949
# Epoch 298/1000
# 59/59 - 0s - loss: 0.3407 - accuracy: 0.8957
# Epoch 299/1000
# 59/59 - 0s - loss: 0.3405 - accuracy: 0.8945
# Epoch 300/1000
# 59/59 - 0s - loss: 0.3394 - accuracy: 0.8950
# Epoch 301/1000
# 59/59 - 0s - loss: 0.3396 - accuracy: 0.8949
# Epoch 302/1000
# 59/59 - 0s - loss: 0.3399 - accuracy: 0.8958
# Epoch 303/1000
# 59/59 - 0s - loss: 0.3391 - accuracy: 0.8954
# Epoch 304/1000
# 59/59 - 0s - loss: 0.3386 - accuracy: 0.8955
# Epoch 305/1000
# 59/59 - 0s - loss: 0.3378 - accuracy: 0.8960
# Epoch 306/1000
# 59/59 - 0s - loss: 0.3378 - accuracy: 0.8965
# Epoch 307/1000
# 59/59 - 0s - loss: 0.3369 - accuracy: 0.8956
# Epoch 308/1000
# 59/59 - 0s - loss: 0.3362 - accuracy: 0.8961
# Epoch 309/1000
# 59/59 - 0s - loss: 0.3357 - accuracy: 0.8965
# Epoch 310/1000
# 59/59 - 0s - loss: 0.3356 - accuracy: 0.8971
# Epoch 311/1000
# 59/59 - 0s - loss: 0.3352 - accuracy: 0.8975
# Epoch 312/1000
# 59/59 - 0s - loss: 0.3354 - accuracy: 0.8970
# Epoch 313/1000
# 59/59 - 0s - loss: 0.3338 - accuracy: 0.8974
# Epoch 314/1000
# 59/59 - 0s - loss: 0.3334 - accuracy: 0.8982
# Epoch 315/1000
# 59/59 - 0s - loss: 0.3324 - accuracy: 0.8985
# Epoch 316/1000
# 59/59 - 0s - loss: 0.3314 - accuracy: 0.8989
# Epoch 317/1000
# 59/59 - 0s - loss: 0.3313 - accuracy: 0.8982
# Epoch 318/1000
# 59/59 - 0s - loss: 0.3307 - accuracy: 0.8997
# Epoch 319/1000
# 59/59 - 0s - loss: 0.3299 - accuracy: 0.8999
# Epoch 320/1000
# 59/59 - 0s - loss: 0.3297 - accuracy: 0.8994
# Epoch 321/1000
# 59/59 - 0s - loss: 0.3285 - accuracy: 0.8997
# Epoch 322/1000
# 59/59 - 0s - loss: 0.3279 - accuracy: 0.9001
# Epoch 323/1000
# 59/59 - 0s - loss: 0.3270 - accuracy: 0.9011
# Epoch 324/1000
# 59/59 - 0s - loss: 0.3272 - accuracy: 0.8999
# Epoch 325/1000
# 59/59 - 0s - loss: 0.3274 - accuracy: 0.9003
# Epoch 326/1000
# 59/59 - 0s - loss: 0.3263 - accuracy: 0.9014
# Epoch 327/1000
# 59/59 - 0s - loss: 0.3257 - accuracy: 0.9009
# Epoch 328/1000
# 59/59 - 0s - loss: 0.3249 - accuracy: 0.9012
# Epoch 329/1000
# 59/59 - 0s - loss: 0.3253 - accuracy: 0.9013
# Epoch 330/1000
# 59/59 - 0s - loss: 0.3260 - accuracy: 0.9007
# Epoch 331/1000
#
# Epoch 00331: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59/59 - 0s - loss: 0.3252 - accuracy: 0.9008
# Epoch 332/1000
# 59/59 - 0s - loss: 0.3228 - accuracy: 0.9024
# Epoch 333/1000
# 59/59 - 0s - loss: 0.3226 - accuracy: 0.9024
# Epoch 334/1000
# 59/59 - 0s - loss: 0.3226 - accuracy: 0.9020
# Epoch 335/1000
# 59/59 - 0s - loss: 0.3222 - accuracy: 0.9022
# Epoch 336/1000
# 59/59 - 0s - loss: 0.3224 - accuracy: 0.9024
# Epoch 337/1000
# 59/59 - 0s - loss: 0.3222 - accuracy: 0.9019
# Epoch 338/1000
#
# Epoch 00338: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 59/59 - 0s - loss: 0.3222 - accuracy: 0.9024
# Epoch 339/1000
# 59/59 - 0s - loss: 0.3212 - accuracy: 0.9030
# Epoch 340/1000
# 59/59 - 0s - loss: 0.3211 - accuracy: 0.9028
# Epoch 341/1000
# 59/59 - 0s - loss: 0.3212 - accuracy: 0.9021
# Epoch 342/1000
# 59/59 - 0s - loss: 0.3211 - accuracy: 0.9024
# Epoch 343/1000
# 59/59 - 0s - loss: 0.3209 - accuracy: 0.9027
# Epoch 344/1000
# 59/59 - 0s - loss: 0.3211 - accuracy: 0.9026
# Epoch 345/1000
# 59/59 - 0s - loss: 0.3208 - accuracy: 0.9032
# Epoch 346/1000
# 59/59 - 0s - loss: 0.3207 - accuracy: 0.9032
# Epoch 347/1000
# 59/59 - 0s - loss: 0.3206 - accuracy: 0.9032
# Epoch 348/1000
# 59/59 - 0s - loss: 0.3207 - accuracy: 0.9031
# Epoch 349/1000
# 59/59 - 0s - loss: 0.3207 - accuracy: 0.9026
# Epoch 350/1000
#
# Epoch 00350: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 59/59 - 0s - loss: 0.3206 - accuracy: 0.9028
# Epoch 351/1000
# 59/59 - 0s - loss: 0.3200 - accuracy: 0.9029
# Epoch 352/1000
# 59/59 - 0s - loss: 0.3199 - accuracy: 0.9032
# Epoch 353/1000
# 59/59 - 0s - loss: 0.3198 - accuracy: 0.9031
# Epoch 354/1000
# 59/59 - 0s - loss: 0.3198 - accuracy: 0.9026
# Epoch 355/1000
# 59/59 - 0s - loss: 0.3198 - accuracy: 0.9033
# Epoch 356/1000
#
# Epoch 00356: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 59/59 - 0s - loss: 0.3198 - accuracy: 0.9035
# Epoch 357/1000
# 59/59 - 0s - loss: 0.3196 - accuracy: 0.9029
# Epoch 358/1000
# 59/59 - 0s - loss: 0.3194 - accuracy: 0.9033
# Epoch 359/1000
# 59/59 - 0s - loss: 0.3195 - accuracy: 0.9033
# Epoch 360/1000
# 59/59 - 0s - loss: 0.3196 - accuracy: 0.9031
# Epoch 361/1000
#
# Epoch 00361: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 59/59 - 0s - loss: 0.3195 - accuracy: 0.9034
# Epoch 362/1000
# 59/59 - 0s - loss: 0.3193 - accuracy: 0.9032
# Epoch 363/1000
# 59/59 - 0s - loss: 0.3194 - accuracy: 0.9033
# Epoch 364/1000
# 59/59 - 0s - loss: 0.3194 - accuracy: 0.9031
# Epoch 365/1000
#
# Epoch 00365: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 59/59 - 0s - loss: 0.3194 - accuracy: 0.9034
# Epoch 366/1000
# 59/59 - 0s - loss: 0.3192 - accuracy: 0.9034
# Epoch 367/1000
# 59/59 - 0s - loss: 0.3193 - accuracy: 0.9031
# Epoch 368/1000
# 59/59 - 0s - loss: 0.3193 - accuracy: 0.9032
# Epoch 369/1000
#
# Epoch 00369: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 59/59 - 0s - loss: 0.3192 - accuracy: 0.9033
# Epoch 370/1000
# 59/59 - 0s - loss: 0.3192 - accuracy: 0.9034
# Epoch 371/1000
# 59/59 - 0s - loss: 0.3192 - accuracy: 0.9033
# Epoch 372/1000
#
# Epoch 00372: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 59/59 - 0s - loss: 0.3192 - accuracy: 0.9034
# Epoch 373/1000
# 59/59 - 0s - loss: 0.3192 - accuracy: 0.9033
# Epoch 374/1000
# 59/59 - 0s - loss: 0.3192 - accuracy: 0.9034
# Epoch 375/1000
#
# Epoch 00375: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 59/59 - 0s - loss: 0.3192 - accuracy: 0.9034
# Epoch 376/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9036
# Epoch 377/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9035
# Epoch 378/1000
#
# Epoch 00378: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9036
# Epoch 379/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9034
# Epoch 380/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9035
# Epoch 381/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9035
# Epoch 382/1000
#
# Epoch 00382: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9034
# Epoch 383/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9035
# Epoch 384/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9034
# Epoch 385/1000
#
# Epoch 00385: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9035
# Epoch 386/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9034
# Epoch 387/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9035
# Epoch 388/1000
#
# Epoch 00388: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9035
# Epoch 389/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9034
# Epoch 390/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9035
# Epoch 391/1000
#
# Epoch 00391: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9034
# Epoch 392/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9034
# Epoch 393/1000
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9034
# Epoch 394/1000
#
# Epoch 00394: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 59/59 - 0s - loss: 0.3191 - accuracy: 0.9034
# {'Test accuracy': 0.9112, 'Number of parameters': 158}

# %% [markdown]
# # Question time
